# %% [markdown]
# Problem 1: Create a Dictionary
#
# Create a dictionary named student that contains the following key-value pairs:
#
# "name": "Alice"
#
# "age": 20
#
# "major": "Computer Science"
#
# Then, print the dictionary and the value associated with the "major" key.

# %%
student ={
    "name": "Alice",
    "age" : 20,
    "major": "Computer Science"
}

# %%
student
# Out:
# {'name': 'Alice', 'age': 20, 'major': 'Computer Science'}

# %%
type(student)
# Out:
# dict

# %%
student['major']
# Out:
# 'Computer Science'

# %% [markdown]
# Problem 2: Update a Dictionary
#
# Using the student dictionary from Problem 1:
#
# Add a new key "GPA" with a value of 3.8
#
# Update the "age" to 21
#
# Print the updated dictionary.

# %%
dir(student)
# Out:
# ['__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__ror__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %%
student.update({"GPA":3.8})

# %%
student
# Out:
# {'name': 'Alice', 'age': 20, 'major': 'Computer Science', 'GPA': 3.8}

# %%
student['age']=21

# %%
student
# Out:
# {'name': 'Alice', 'age': 21, 'major': 'Computer Science', 'GPA': 3.8}

# %% [markdown]
# Problem 3: Check Key Existence
#
# Write code to check if the key "GPA" exists in the student dictionary.
# If it exists, print "GPA is available", otherwise print "GPA not found".

# %%
student.keys()
# Out:
# dict_keys(['name', 'age', 'major', 'GPA'])

# %%
student.values()
# Out:
# dict_values(['Alice', 21, 'Computer Science', 3.8])

# %%
#########

# %% [markdown]
# company = {
#     "HR": {"manager": "Fatima", "employees": {"E1": "Ali", "E2": "Usman"}},
#     "IT": {"manager": "Khalid", "employees": {"E3": "Sara", "E4": "Bilal"}},
#     "Finance": {"manager": "Zara", "employees": {"E5": "Hassan", "E6": "Nadia"}}
# }

# %% [markdown]
# Problem 1: Print All Departments
#
# Write code to print the names of all departments in the company.

# %%
company = {
    "HR": {"manager": "Fatima", "employees": {"E1": "Ali", "E2": "Usman"}},
    "IT": {"manager": "Khalid", "employees": {"E3": "Sara", "E4": "Bilal"}},
    "Finance": {"manager": "Zara", "employees": {"E5": "Hassan", "E6": "Nadia"}}
}

# %%
for department in company:
  print(department)
# Out:
# HR
# IT
# Finance

# %% [markdown]
# Problem 2: Print Manager of IT
#
# Write code to print the name of the manager of the IT department.

# %%
company["IT"]['manager']
# Out:
# 'Khalid'

# %% [markdown]
# Problem 3: Print All Employees in HR
#
# Write code to print the names of all employees in the HR department.

# %%
company["HR"]["employees"]['E1']
# Out:
# 'Ali'

# %%
company["HR"]["employees"]['E2']
# Out:
# 'Usman'

# %%
for employee in company['HR']['employees']:
   print(company['HR']['employees'])
# Out:
# {'E1': 'Ali', 'E2': 'Usman'}
# {'E1': 'Ali', 'E2': 'Usman'}

# %%
for employee in company['HR']['employees'].values():
   print(employee)
# Out:
# Ali
# Usman

# %%
dir({})
# Out:
# ['__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__ror__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']
